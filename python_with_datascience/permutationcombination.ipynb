# %%
# Python code to demonstrate 
# to find all permutation of 
# a given string 

# Initialising string

ini_str =input("enter a number")

# Printing initial string 
#print("Initial string", ini_str) 

# Finding all permuatation 
result = [] 

def permute(data, i, length): 
	if i == length: 
		result.append(''.join(data) ) 
	else: 
		for j in range(i, length): 
			# swap 
			data[i], data[j] = data[j], data[i] 
			permute(data, i + 1, length) 
			data[i], data[j] = data[j], data[i] 
permute(list(ini_str), 0, len(ini_str)) 

# Printing result 
#print("Resultant permutations", str(result)) 
flag=0
for i in result:
    if int(i)%60==0:
        print("red")
        flag=1
        break
if flag==0:
    print("cyan")

# %%
# Python code to demonstrate 
# to find all permutation of 
# a given string 

# Initialising string
l=[]
for i in range(0,6):
    l =input()

# Printing initial string 
#print("Initial string", ini_str) 

# Finding all permuatation 
result = [] 
lst=[]

def permute(data, i, length): 
	if i == length: 
		return result.append(''.join(data) ) 
	else: 
		for j in range(i, length): 
			# swap 
			data[i], data[j] = data[j], data[i] 
			permute(data, i + 1, length) 
			data[i], data[j] = data[j], data[i] 
            
            
            

# Printing result 
#print("Resultant permutations", str(result)) 
for ini_str in l:            
    lst=permute(list(ini_str), 0, len(ini_str))  
    
for result in lst:
    flag=0
    for i in result:
        if int(i)%60==0:
            print("red")
            flag=1
            break
        if flag==0:
            print("cyan")
