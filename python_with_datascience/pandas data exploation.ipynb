# %%
import pandas as pd
data=pd.read_csv("C:\\Users\\SUMANTA KR MAJI\\home.csv")
print(data.head())
print('MAX PRICE: ',data["price"].max())
print('Min PRICE: ',data["price"].min())
print('SUM OF  PRICE: ',data["price"].sum())
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# MAX PRICE:  848473
# Min PRICE:  43784
# SUM OF  PRICE:  4069646

# %%
import pandas as pd
data1=pd.read_csv("D:\\student.csv")
print(data1.head())
# Out:
#       name   roll  maks
# 0   sumanta    12   400
# 1       ram    23   490
# 2    shruti    24   420
# 3    saheli    23   350
# 4  sanjukta    12   300

# %%
#writing a dictionary in an csv file using csv

import csv
mydict=[{'f_name':'sumanta','l_name':'maji','pay':200000},
        {'f_name':'akash','l_name':'paul','pay':30000},
        { 'f_name':"ram",'l_name':"bhat",'pay':400000}
    ]


fields=['f_name','l_name','pay']

filename="D:\\student_details.csv"

with open(filename,'w') as csvfile:
    csvwriter = csv.DictWriter(csvfile,fieldnames=fields)
    csvwriter.writeheader() 
    csvwriter.writerows(mydict)

# %%
import csv

with open("D:\\student_details1.csv", 'w', newline='') as csvfile:
    fieldnames = ['first_name', 'last_name']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'first_name': 'Baked', 'last_name': 'Beans'})
    writer.writerow({'first_name': 'Lovely', 'last_name': 'Spam'})
    writer.writerow({'first_name': 'Wonderful', 'last_name': 'Spam'})

# %%
#writing a dictionary in an excle file using pandas library
import pandas as pd
 
my_dict=[{'first_name': 'Baked', 'last_name': 'Beans'},
    
    {'first_name': 'Lovely', 'last_name': 'Spam'},
    {'first_name': 'Wonderful', 'last_name': 'Spam'}
    
]

df=pd.DataFrame(my_dict)#converting a dictionary into a dataframe
df.to_csv("D:\\student_details20.csv",index=False)

# %%
import json


file='D:\\xyz.json'
o= open(file,)
# this data is jason formate data

#we have to convert it in python json to python
#we have to parse y:




z=json.loads(o)

print(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-ecc02109239b> in <module>
#      12
#      13
# ---> 14 z=json.loads(o)
#      15
#      16 print(z)
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not TextIOWrapper

# %%
import pandas as pd
file='D:\\xyz.json'

json_data=pd.read_json(file)

for i in json_data['Employee_details']:
    print(i["Employee_name"],end="      ")
    print(i["email"])
# Out:
# ram      ram@gmail.com
# akash      akash@gmail.com
# sumanta      sumanta@gmail.com

# %%
import requests
import pandas as pd
url='https://www.w3schools.com/js/js_json_intro.asp'

html_data =requests.get(url)
    
#<Response [200]> it means that we are able to connect with the web server
x=pd.read_html(html_data.text)
# Out:
# <Response [200]>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f94894748c4a> in <module>
#       6
#       7 print(html_data)#<Response [200]> it means that we are able to connect with the web server
# ----> 8 x=pd.read_html(html_data.text)
#       9 print(x)
#      10
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
# ...

# %%
#titanic data exploration

import pandas as pd
df= pd.read_csv('D:\\titanic_train.csv')#loading the csv data
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
df.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# ...

# %%
df1 = pd.read_csv('D:\\titanic_train.csv',usecols=["PassengerId","Survived","Ticket","Name"])
df1.head()
# Out:
#    PassengerId  Survived                                               Name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#              Ticket
# 0         A/5 21171
# 1          PC 17599
# 2  STON/O2. 3101282
# 3            113803
# 4            373450

# %%
df2=df.drop(["SibSp","Parch","Cabin"],axis="columns")
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
df1 = pd.read_csv('D:\\titanic_train.csv',index_col="Pclass")
df1.head(20)
# Out:
#         PassengerId  Survived  \
# Pclass
# 3                 1         0
# 1                 2         1
# 3                 3         1
# 1                 4         1
# 3                 5         0
# 3                 6         0
# 1                 7         0
# 3                 8         0
# 3                 9         1
# 2                10         1
# 3                11         1
# 1                12         1
# 3                13         0
# 3                14         0
# 3                15         0
# 2                16         1
# 3                17         0
# 2                18         1
# 3                19         0
# 3                20         1
#
#                                                      Name     Sex   Age  \
# Pclass
# 3                                 Braund, Mr. Owen Harris    male  22.0
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                  Heikkinen, Miss. Laina  female  26.0
# ...

# %%
#getting some inforation from the data set with .describe()and .info()
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#sorting the data frame based on a column

df.sort_values("Fare",ascending=False).head(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259         1       1
# 737          738         1       1
# 679          680         1       1
# 88            89         1       1
# 27            28         0       1
# 341          342         1       1
# 438          439         0       1
# 311          312         1       1
# 742          743         1       1
# 118          119         0       1
# 299          300         1       1
# 557          558         0       1
# 700          701         1       1
# 380          381         1       1
# 716          717         1       1
# 527          528         0       1
# 377          378         0       1
# 730          731         1       1
# 779          780         1       1
# 689          690         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 258                                   Ward, Miss. Anna  female  35.0      0
# ...

# %%
df["Sex"].value_counts().head(30)#using value counts method to count the occurence of each variable in a column
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#using .nunique() to count number of unique values that occur in a column
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df["Age"].nunique()
# Out:
# 88

# %%
#how to filter data from our data frame 

df[       (df.Sex=="female")  & (df.Age<20)             ].head(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 22            23         1       3
# 24            25         0       3
# 38            39         0       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 49            50         0       3
# 58            59         1       2
# 68            69         1       3
# 71            72         0       3
# 84            85         1       2
# 111          112         0       3
# 114          115         0       3
# 119          120         0       3
# 136          137         1       1
# 147          148         0       3
# 156          157         1       3
#
#                                               Name     Sex   Age  SibSp  \
# 9              Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %%
df[(df.Survived==1) & (df.Age==20)]
# Out:
#      PassengerId  Survived  Pclass                         Name   Sex   Age  \
# 622          623         1       3             Nakid, Mr. Sahid  male  20.0
# 664          665         1       3  Lindqvist, Mr. Eino William  male  20.0
# 762          763         1       3        Barah, Mr. Hanna Assi  male  20.0
#
#      SibSp  Parch             Ticket     Fare Cabin Embarked
# 622      1      1               2653  15.7417   NaN        C
# 664      1      0  STON/O 2. 3101285   7.9250   NaN        S
# 762      0      0               2663   7.2292   NaN        C

# %%
df[(df.Embarked=="C")]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df.Pclass==1)&(df.Age==20)]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[(df.Pclass==1)&(df.Sex=="male")&(df.Survived==0)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 30            31         0       1              Uruchurtu, Don. Manuel E
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 806          807         0       1                Andrews, Mr. Thomas Jr
# 815          816         0       1                      Fry, Mr. Richard
# 822          823         0       1       Reuchlin, Jonkheer. John George
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
#iloc   index location

df["Age"]
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.iloc[ [0,3,5,9]    ,  [3,4,7]  ]
# Out:
#                                            Name     Sex  Parch
# 0                       Braund, Mr. Owen Harris    male      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      0
# 5                              Moran, Mr. James    male      0
# 9           Nasser, Mrs. Nicholas (Adele Achem)  female      0

# %%
df.iloc[  0:10    , 0:5   ]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male
# 6                            McCarthy, Mr. Timothy J    male
# 7                     Palsson, Master. Gosta Leonard    male
# ...

# %%
df.iloc[0:10 ,  -3]
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# 5     8.4583
# 6    51.8625
# 7    21.0750
# 8    11.1333
# 9    30.0708
# Name: Fare, dtype: float64

# %%
df.iloc[[-30,-20,-40]    ,    [-1,-4]]
# Out:
#     Embarked  Ticket
# 861        S   28134
# 871        S   11751
# 851        S  347060

# %%
import seaborn as sns
sns.set(style="darkgrid")
b=sns.swarmplot(y="Age",x="Pclass",hue="Sex",dodge=True,data=df,)

# %%
ax = sns.swarmplot(x="Sex", y="Age", data=df,order=["male","female"],size=10)

# %%
ax = sns.swarmplot(y="Sex", x="Age", data=df,order=["male","female"],size=10)

# %% [markdown]
# # karnal density estimation (here we will plot the age in each passenger class separately it belongs

# %%
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(30,15))
for x in [1,2,3]:
    
      df.Age[df.Pclass==x].plot(kind="kde")
plt.legend(("1st","2nd","3rd"))

# %%
import seaborn
sns.heatmap(df.isnull(),yticklabels=False,xticklabels=False,cbar=False,cmap='viridis')

# %%
sns.countplot(x='Survived',hue="Pclass",data=df)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 7))
sns.boxplot(x='Pclass',y='Age',data=df,palette='winter')
